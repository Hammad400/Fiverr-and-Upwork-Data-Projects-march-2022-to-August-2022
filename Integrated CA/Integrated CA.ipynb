# %% [markdown]
# ## First section (30 marks)
# This section contains hypothesis testing.

# %% [markdown]
# #### Importing python libraries and dataset.

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
pd.options.mode.chained_assignment = None  # default='warn'

# %%
import scipy.stats as stats

# %% [markdown]
# Here above following python libraries are imported in program:<br>
# 1)pandas: <br>
# pandas is used for data crunching. <br>
# 2)numpy :
# It is used for scientific computing it provides some mathematics and statistics like functions. <br>
# 3)Matplotlib:
# It is used for data Visualization For example to make Charts and graphs. <br>
# 4)Seaborn:
# It is also used for data Visualization For example to make Charts and graphs.<br>
# 5)Scipy:<br>
# it is used for statistical operations.
#
# Now here I am loading data. As data is in excel csv  file so I am importing csv file with .csv file format.<br>
# Here df is a data frame which stores excel csv file .<br>

# %%
df=pd.read_csv('dataset 10k.csv')
df
# Out:
#          month       state    permit permit_recheck  handgun  long_gun  \
# 0      2022-02     Alabama     25401            499  21822.0   14541.0
# 1      2022-02      Alaska       301              0   2644.0    2178.0
# 2      2022-02     Arizona      2560            473  20150.0    9935.0
# 3      2022-02    Arkansas      1842            309   7780.0    5756.0
# 4      2022-02  California     15815          10550  36362.0   23017.0
# ...        ...         ...       ...            ...      ...       ...
# 15395  1998-11    Virginia         0                    14.0       2.0
# 15396  1998-11  Washington         1                    65.0     286.0
# 15397  1998-11        West  Virginia              3      NaN     149.0
# 15398  1998-11   Wisconsin         0                    25.0     214.0
# 15399  1998-11     Wyoming         8                    45.0      49.0
#
#         other  multiple  admin  prepawn_handgun  ...  rentals_long_gun  \
# 0      1351.0    1260.0    0.0             13.0  ...               0.0
# 1       348.0     202.0    0.0              0.0  ...               0.0
# 2      1690.0    1153.0    0.0             11.0  ...               0.0
# 3       429.0     515.0    4.0             15.0  ...               0.0
# 4      4941.0       1.0    0.0              1.0  ...               0.0
# ...       ...       ...    ...              ...  ...               ...
# 15395     NaN       8.0    0.0              NaN  ...               NaN
# 15396     NaN       8.0    1.0              NaN  ...               NaN
# 15397   251.0       NaN    5.0              0.0  ...               NaN
# 15398     NaN       2.0    0.0              NaN  ...               NaN
# 15399     NaN       5.0    0.0              NaN  ...               NaN
#
#        private_sale_handgun  private_sale_long_gun  private_sale_other  \
# 0                      28.0                   29.0                 2.0
# 1                       2.0                    4.0                 0.0
# 2                      15.0                   13.0                 0.0
# 3                       5.0                   11.0                 1.0
# 4                    7638.0                 3090.0               626.0
# ...                     ...                    ...                 ...
# 15395                   NaN                    NaN                 NaN
# 15396                   NaN                    NaN                 NaN
# 15397                   NaN                    NaN                 NaN
# 15398                   NaN                    NaN                 NaN
# 15399                   NaN                    NaN                 NaN
#
#        return_to_seller_handgun  return_to_seller_long_gun  \
# 0                           1.0                        0.0
# 1                           0.0                        0.0
# 2                           0.0                        2.0
# 3                           0.0                        0.0
# 4                          19.0                       20.0
# ...                         ...                        ...
# 15395                       NaN                        NaN
# 15396                       NaN                        NaN
# 15397                       NaN                        NaN
# 15398                       NaN                        NaN
# 15399                       NaN                        NaN
#
#        return_to_seller_other    totals    V28  V29
# 0                         0.0   69098.0    NaN  NaN
# 1                         0.0    5916.0    NaN  NaN
# 2                         0.0   38149.0    NaN  NaN
# 3                         0.0   19002.0    NaN  NaN
# 4                         0.0  106295.0    NaN  NaN
# ...                       ...       ...    ...  ...
# 15395                     NaN      24.0    NaN  NaN
# 15396                     NaN     361.0    NaN  NaN
# 15397                     NaN       NaN  408.0  NaN
# 15398                     NaN     241.0    NaN  NaN
# 15399                     NaN     107.0    NaN  NaN
#
# [15400 rows x 29 columns]

# %% [markdown]
# ##### Filling null values with zero:

# %%
df[['handgun','long_gun']]=df[['handgun','long_gun']].fillna(0)
df[['handgun','long_gun']].isnull().sum()
# Out:
# handgun     0
# long_gun    0
# dtype: int64

# %% [markdown]
# As these two features are used in all process so null values of that features are filled with zero.

# %% [markdown]
# #### Sample selection:

# %% [markdown]
# Here a sample containing 10 values are chosen for hypothesis testing.

# %%
sample_size=10
sample=np.random.choice(df['handgun'],sample_size)
sample
# Out:
# array([0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        8.2370e+03, 1.7976e+04, 3.1230e+03, 2.2730e+03, 8.0000e+00])

# %%
sample.mean()
# Out:
# 3161.7

# %% [markdown]
# The mean of sample is 9807.6.

# %% [markdown]
# #### hypothesis test:T test

# %% [markdown]
# <pre>
# Hypothesis testing:
#
# Hypothesis testing is a statistical method that is used in making statistical decisions using experimental data. Hypothesis Testing is basically an assumption that we make about the population parameter.
# Hypothesis testing is an essential procedure in statistics. A hypothesis test evaluates two mutually exclusive statements about a population to determine which statement is best supported by the sample data. When we say that a finding is statistically significant, it’s thanks to a hypothesis test
# Techniques used in hypothesis testing:
# •	T Test (Student T test)
# •	Z Test
# •	ANOVA Test
# •	Chi-Square Test
# Which is important parameter of hypothesis testing?
# Null hypothesis:-
# In inferential statistics, the null hypothesis is a general statement or default position that there is no relationship between two measured phenomena, or no association among groups
# In other words it is a basic assumption or made based on domain or problem knowledge.
# Example:
# A company production is = 50 unit/per day etc.
# Alternative hypothesis:-
# The alternative hypothesis is the hypothesis used in hypothesis
# Testing that is contrary to the null hypothesis. It is usually taken to be that the observations are the result of a real effect (with some amount of chance variation superposed)
# Example: a company production is !=50 unit/per day etc.
# <pre>

# %% [markdown]
# #### T test:
# A t-test is a type of inferential statistic which is used to determine if there is a significant difference between the means of two groups which may be related in certain features. It is mostly used when the data sets, like the set of data recorded as out come from flipping a coin a 100 times, would follow a normal distribution and may have unknown
# Variances
# T test is used as a Hypothesis testing tool, which allows testing of an assumption applicable to a population.
# T-test has 2 types:
# 1. One sampled t-test
# 2. Two-sampled t-test.

# %% [markdown]
# Note: here one sample t test is used.
# One sample t-test
# It determines whether the sample mean is statistically different from a known or hypothesized population mean. The One Sample
# T Test is a parametric test.
# Example: - you have 10 ages and you are checking whether average age is 30 or not.

# %% [markdown]
# Test, whether the population mean, is less than 7000.
# Hypothesis
#
# H0: There is no significant mean difference i.e., μ = 7000
# H1: The population mean is less than 7000. i.e., μ < 7000
# Here H0 is null hypothesis and H1 is alternative hypothesis.
# Here level of significance (alpha) is 0.05 or 5%.

# %%
from scipy.stats import ttest_1samp

# %%
ttest,p_value=ttest_1samp(sample,7000)

# %%
print(p_value)
# Out:
# 0.06706798433605653

# %%
if p_value < 0.05:    # alpha value is 0.05 or 5%
    print(" we are rejecting null hypothesis")
else:
    print("we are accepting null hypothesis")
# Out:
# we are accepting null hypothesis

# %% [markdown]
# As p value is greater than level of significance so null hypothesis is accepted .
# So there is no significant difference between population mean and hypothesized mean.

# %% [markdown]
# ## Second section (30 marks)
# This section contains correlation analysis.

# %% [markdown]
# <pre>
# Correlation analysis:
#
# Correlation Analysis is statistical method that is used to discover if there is a relationship between two variables/datasets, and how strong that relationship.
# It is basically measure of degree of relatedness of variables.
# On the basis of strength it is divided as 5 types.
# •	Strong negative correlation
# •	Moderate negative correlation
# •	Strong positive correlation
# •	Moderate positive correlation
# •	No correaltion
#
# A correlation coefficient is a way to put a value to the relationship. Correlation coefficients have a value of between -1 and 1. A “0” means there is no relationship between the variables at all, while -1 or 1 means that there is a perfect negative or positive correlation.
# The most common correlation coefficient is the Pearson Correlation Coefficient.
# Note: in this section the Pearson Correlation Coefficient is used.
#
# <pre>

# %% [markdown]
# ##### Correlation Coefficient using numpy:
# Here two variables which are hand gun and long_gun are used for correlation analysis so I have to find what type of relationship hand gun and long gun feature have?

# %%
np.corrcoef(df['handgun'],df['long_gun'])
# Out:
# array([[1.        , 0.64202673],
#        [0.64202673, 1.        ]])

# %% [markdown]
# <pre>
# The Correlation Coefficient of handgun and long gun is 0.64 which show a strong positive relationship between handgun and long_gun feature.
# So this positive relationship states that if value of hand gun increased than it tends to increase in the value of long gun.
# So let us understand the relationship using scatter plot
# <pre>

# %%
plt.figure()
sns.scatterplot(df['handgun'],df['long_gun'])
plt.show()
# Out:
# c:\users\sk\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Scatterplot to show relationship:
# Here scatterplot is used to show relationship between handgun and long gun.
# As by looking on scatter plot positive relationship is shown between hand gun and long gun.

# %% [markdown]
# ##### Correlation matrix:
# This correlation matrix shows that how features are correlated with each other.

# %%
df.corr()
# Out:
#                             handgun  long_gun     other  multiple     admin  \
# handgun                    1.000000  0.642027 -0.046369  0.410180  0.005636
# long_gun                   0.642027  1.000000  0.040290  0.323256  0.033009
# other                     -0.046369  0.040290  1.000000  0.265127  0.351968
# multiple                   0.410180  0.323256  0.265127  1.000000  0.006929
# admin                      0.005636  0.033009  0.351968  0.006929  1.000000
# prepawn_handgun            0.174942  0.174003  0.169013  0.176335 -0.001965
# prepawn_long_gun           0.144965  0.211945  0.089596  0.131481 -0.010323
# prepawn_other             -0.099046 -0.065670  0.506845  0.096968  0.267444
# redemption_handgun         0.574578  0.454828 -0.010301  0.413633 -0.013863
# redemption_long_gun        0.329700  0.394597  0.120110  0.292816  0.018876
# redemption_other          -0.186216 -0.128019  0.582129  0.014544  0.381092
# returned_handgun           0.546791  0.377354  0.008250  0.251858 -0.011763
# returned_long_gun          0.135060  0.128364  0.332762  0.111447  0.058006
# returned_other            -0.026279  0.014632  0.317419  0.112512  0.110431
# rentals_handgun           -0.050465 -0.044224  0.022303 -0.016736  0.100532
# rentals_long_gun          -0.082907 -0.096762  0.121589  0.003876  0.018327
# private_sale_handgun       0.146839  0.140862  0.083607  0.011568 -0.020169
# private_sale_long_gun      0.127674  0.150424  0.182203  0.079325  0.008474
# private_sale_other         0.046300  0.115007  0.478020  0.211302  0.106910
# return_to_seller_handgun   0.216832  0.195533  0.386327  0.412828  0.072278
# return_to_seller_long_gun  0.311578  0.217464  0.203914  0.384207  0.004666
# return_to_seller_other    -0.049056  0.042524  0.514547  0.260030  0.144504
# totals                     0.553743  0.428509 -0.016087  0.253976 -0.002030
# V28                        0.222443  0.445366  0.730465  0.572694  0.480746
# V29                        0.987955  0.144532  0.955170  0.157306 -0.027206
#
#                            prepawn_handgun  prepawn_long_gun  prepawn_other  \
# handgun                           0.174942          0.144965      -0.099046
# long_gun                          0.174003          0.211945      -0.065670
# other                             0.169013          0.089596       0.506845
# multiple                          0.176335          0.131481       0.096968
# admin                            -0.001965         -0.010323       0.267444
# prepawn_handgun                   1.000000          0.455603       0.011526
# prepawn_long_gun                  0.455603          1.000000       0.167503
# prepawn_other                     0.011526          0.167503       1.000000
# redemption_handgun                0.427479          0.435746      -0.014470
# redemption_long_gun               0.359803          0.592691       0.180640
# redemption_other                 -0.059524          0.070667       0.726447
# returned_handgun                  0.031398          0.149944      -0.036503
# returned_long_gun                 0.015953          0.077412       0.252077
# returned_other                   -0.022149          0.014765       0.124948
# rentals_handgun                  -0.014275         -0.022399       0.019037
# rentals_long_gun                 -0.019154         -0.010738       0.082218
# private_sale_handgun              0.015401          0.039388      -0.006815
# private_sale_long_gun             0.016443          0.079574       0.007153
# private_sale_other               -0.003043          0.097555       0.055523
# return_to_seller_handgun          0.094472          0.069901       0.010569
# return_to_seller_long_gun         0.179986          0.146606       0.003871
# return_to_seller_other           -0.004327          0.039476       0.067366
# totals                            0.164243          0.076878      -0.053884
# V28                               0.087253          0.266503       0.414710
# V29                               0.639914          0.082317            NaN
#
#                            redemption_handgun  redemption_long_gun  ...  \
# handgun                              0.574578             0.329700  ...
# long_gun                             0.454828             0.394597  ...
# other                               -0.010301             0.120110  ...
# multiple                             0.413633             0.292816  ...
# admin                               -0.013863             0.018876  ...
# prepawn_handgun                      0.427479             0.359803  ...
# prepawn_long_gun                     0.435746             0.592691  ...
# prepawn_other                       -0.014470             0.180640  ...
# redemption_handgun                   1.000000             0.806806  ...
# redemption_long_gun                  0.806806             1.000000  ...
# redemption_other                    -0.105828             0.201543  ...
# returned_handgun                     0.208334             0.039114  ...
# returned_long_gun                   -0.028785             0.074485  ...
# returned_other                      -0.054876             0.010158  ...
# rentals_handgun                     -0.033204            -0.023320  ...
# rentals_long_gun                    -0.057593             0.010527  ...
# private_sale_handgun                 0.039833             0.012158  ...
# private_sale_long_gun                0.044037             0.008663  ...
# private_sale_other                  -0.019497            -0.038352  ...
# return_to_seller_handgun             0.178472             0.048526  ...
# return_to_seller_long_gun            0.284223             0.108574  ...
# return_to_seller_other              -0.019473            -0.011461  ...
# totals                               0.351024             0.237376  ...
# V28                                  0.379630             0.641503  ...
# V29                                       NaN                  NaN  ...
#
#                            rentals_long_gun  private_sale_handgun  \
# handgun                           -0.082907              0.146839
# long_gun                          -0.096762              0.140862
# other                              0.121589              0.083607
# multiple                           0.003876              0.011568
# admin                              0.018327             -0.020169
# prepawn_handgun                   -0.019154              0.015401
# prepawn_long_gun                  -0.010738              0.039388
# prepawn_other                      0.082218             -0.006815
# redemption_handgun                -0.057593              0.039833
# redemption_long_gun                0.010527              0.012158
# redemption_other                   0.138949             -0.017593
# returned_handgun                  -0.047192              0.569818
# returned_long_gun                  0.075855              0.612442
# returned_other                     0.079320              0.278307
# rentals_handgun                    0.002991             -0.008870
# rentals_long_gun                   1.000000             -0.014340
# private_sale_handgun              -0.014340              1.000000
# private_sale_long_gun             -0.000225              0.935662
# private_sale_other                 0.061445              0.651425
# return_to_seller_handgun           0.037627              0.381233
# return_to_seller_long_gun         -0.006054              0.334616
# return_to_seller_other             0.089035              0.023033
# totals                            -0.062180              0.069526
# V28                                0.049417              0.590330
# V29                                0.672640                   NaN
#
#                            private_sale_long_gun  private_sale_other  \
# handgun                                 0.127674            0.046300
# long_gun                                0.150424            0.115007
# other                                   0.182203            0.478020
# multiple                                0.079325            0.211302
# admin                                   0.008474            0.106910
# prepawn_handgun                         0.016443           -0.003043
# prepawn_long_gun                        0.079574            0.097555
# prepawn_other                           0.007153            0.055523
# redemption_handgun                      0.044037           -0.019497
# redemption_long_gun                     0.008663           -0.038352
# redemption_other                       -0.028616            0.007039
# returned_handgun                        0.564156            0.385194
# returned_long_gun                       0.577276            0.429067
# returned_other                          0.313391            0.402492
# rentals_handgun                        -0.009534           -0.003298
# rentals_long_gun                       -0.000225            0.061445
# private_sale_handgun                    0.935662            0.651425
# private_sale_long_gun                   1.000000            0.777715
# private_sale_other                      0.777715            1.000000
# return_to_seller_handgun                0.497631            0.662778
# return_to_seller_long_gun               0.419003            0.401351
# return_to_seller_other                  0.221325            0.648361
# totals                                  0.052025           -0.008649
# V28                                     0.143593            0.271839
# V29                                          NaN                 NaN
#
#                            return_to_seller_handgun  \
# handgun                                    0.216832
# long_gun                                   0.195533
# other                                      0.386327
# multiple                                   0.412828
# admin                                      0.072278
# prepawn_handgun                            0.094472
# prepawn_long_gun                           0.069901
# prepawn_other                              0.010569
# redemption_handgun                         0.178472
# redemption_long_gun                        0.048526
# redemption_other                          -0.008102
# returned_handgun                           0.501642
# returned_long_gun                          0.290143
# returned_other                             0.285486
# rentals_handgun                           -0.004663
# rentals_long_gun                           0.037627
# private_sale_handgun                       0.381233
# private_sale_long_gun                      0.497631
# private_sale_other                         0.662778
# return_to_seller_handgun                   1.000000
# return_to_seller_long_gun                  0.825885
# return_to_seller_other                     0.490646
# totals                                     0.055619
# V28                                        0.261584
# V29                                             NaN
#
#                            return_to_seller_long_gun  return_to_seller_other  \
# handgun                                     0.311578               -0.049056
# long_gun                                    0.217464                0.042524
# other                                       0.203914                0.514547
# multiple                                    0.384207                0.260030
# admin                                       0.004666                0.144504
# prepawn_handgun                             0.179986               -0.004327
# prepawn_long_gun                            0.146606                0.039476
# prepawn_other                               0.003871                0.067366
# redemption_handgun                          0.284223               -0.019473
# redemption_long_gun                         0.108574               -0.011461
# redemption_other                           -0.031098                0.053455
# returned_handgun                            0.606330                0.016749
# returned_long_gun                           0.256960                0.067583
# returned_other                              0.152057                0.286595
# rentals_handgun                            -0.006751                0.013619
# rentals_long_gun                           -0.006054                0.089035
# private_sale_handgun                        0.334616                0.023033
# private_sale_long_gun                       0.419003                0.221325
# private_sale_other                          0.401351                0.648361
# return_to_seller_handgun                    0.825885                0.490646
# return_to_seller_long_gun                   1.000000                0.241731
# return_to_seller_other                      0.241731                1.000000
# totals                                      0.106314               -0.059214
# V28                                         0.290820                0.261649
# V29                                              NaN                     NaN
#
#                              totals       V28       V29
# handgun                    0.553743  0.222443  0.987955
# long_gun                   0.428509  0.445366  0.144532
# other                     -0.016087  0.730465  0.955170
# multiple                   0.253976  0.572694  0.157306
# admin                     -0.002030  0.480746 -0.027206
# prepawn_handgun            0.164243  0.087253  0.639914
# prepawn_long_gun           0.076878  0.266503  0.082317
# prepawn_other             -0.053884  0.414710       NaN
# redemption_handgun         0.351024  0.379630       NaN
# redemption_long_gun        0.237376  0.641503       NaN
# redemption_other          -0.109056  0.515154  0.230997
# returned_handgun           0.177857  0.593666       NaN
# returned_long_gun          0.015536  0.408865       NaN
# returned_other            -0.031941  0.333330  0.292655
# rentals_handgun           -0.036299 -0.016953  0.053271
# rentals_long_gun          -0.062180  0.049417  0.672640
# private_sale_handgun       0.069526  0.590330       NaN
# private_sale_long_gun      0.052025  0.143593       NaN
# private_sale_other        -0.008649  0.271839       NaN
# return_to_seller_handgun   0.055619  0.261584       NaN
# return_to_seller_long_gun  0.106314  0.290820       NaN
# return_to_seller_other    -0.059214  0.261649       NaN
# totals                     1.000000  0.162783       NaN
# V28                        0.162783  1.000000       NaN
# V29                             NaN       NaN  1.000000
#
# [25 rows x 25 columns]

# %%
df.corr()['handgun']['long_gun']
# Out:
# 0.6420267291566981

# %% [markdown]
# So this method also shows that the correlation coefficient of hand gun and long gun is 0.64.

# %% [markdown]
# #### Heat map of correlation:

# %% [markdown]
# This is heat map of correlation which shows correlation coefficient between each other.

# %%
plt.figure(figsize=(16,9))
sns.heatmap(df.corr(),cmap ='cividis',linewidth = 0.30, annot = True)
plt.show()

# %% [markdown]
# ## Third section (30 marks)

# %% [markdown]
# <pre>
# This is Machine Learning based section in which I have to build Linear Regression model between chosen features and also I have to evaluate Linear Regression Model that how it performs?
# So as in 2nd section hand gun and long gun are selected so in this section are used in Machine Learning
#
# <pre>

# %% [markdown]
# #### Splitting into dependent and independent feature:
# Here below data frame is divided into dependent and Independent feature. Dependent feature is output for training process and Independent features are inputs for machine learning process.

# %%
X=df[['handgun']]

# %%
y=df['long_gun']

# %% [markdown]
# Here hand gun feature is independent feature or inputs and long gun is dependent feature or outputs so inputs are stored as X and output is stored as y.

# %% [markdown]
# #### Splitting into train and test:

# %% [markdown]
# Here data is further divided into train and test data as train data is used to train model and test data is used to test performance of model because test data is unseen to machine learning model.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30)

# %% [markdown]
# Here train and test data is divided in the ratio of 80:20 means to say that 80 % of total data is training data and 20 % of total data is test data.

# %% [markdown]
# #### Building a Linear Regression Model:
# Linear regression is one the Supervised Machine Learning technique used for regression. It is used for predicting the continuous dependent variable using a given set of independent variables. Linear regression predicts the output of a continuous dependent variable.

# %%
from sklearn.linear_model import LinearRegression
LR= LinearRegression()
LR.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### Accuracy score of Linear Regression Model:
#  Accuracy score or R2 score is a very important metric that is used to evaluate the performance of a regression-based machine learning model. It is pronounced as R squared and is also known as the coefficient of determination. It works by measuring the amount of variance in the predictions explained by the dataset

# %%
LR.score(X_test, y_test)
# Out:
# 0.40764687089163965

# %% [markdown]
# So the accuracy score is 40% which is very low.

# %% [markdown]
# #### Mean Squared Error and Root Mean square error:
# Root mean squared error (RMSE) is the square root of the mean of the square of all of the error. The use of RMSE is very common

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
predictions = LR.predict(X_test)
mse = mean_squared_error(y_test,predictions)
rmse = np.sqrt(mse)
print(mse)
print(rmse)
# Out:
# 51794976.09900603
# 7196.872661024789

# %% [markdown]
# Here Mean Squared error is 51794976 and Root Mean Squared error is 7196.

# %% [markdown]
# #### Mean Absolute Error:

# %% [markdown]
# Mean absolute error refers to the magnitude of difference between the prediction of an observation and the true value of that observation. MAE takes the average of absolute errors for a group of predictions and observations as a measurement of the magnitude of errors for the entire group.

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test,predictions)
# Out:
# 3875.860363266269

# %% [markdown]
# Mean Absolute Error is 3875.
